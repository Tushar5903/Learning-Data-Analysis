# %%
import pandas as pd

# %%
df = pd.read_csv("data_cleaning_sample.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df2 = df.dropna()
df2
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df2.duplicated()
# Out:
# 0    False
# 2    False
# 4    False
# 6     True
# 7     True
# dtype: bool

# %%
df2.drop_duplicates()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019

# %%
df2["Name"].str.upper()
# Out:
# 0    ALICE
# 2      BOB
# 4    DAVID
# 6    ALICE
# 7    ALICE
# Name: Name, dtype: str

# %%
df2["City"].str.lower()
# Out:
# 0       new york
# 2    los angeles
# 4         mumbai
# 6       new york
# 7       new york
# Name: City, dtype: str

# %%
df["Age"] = df["Age"].fillna(0).astype(int)
df
# Out:
#       Name  Age         City Gender              Email   Join Date
# 0    Alice   25     New York      F  alice@example.com  01-05-2021
# 1  Charlie    0        Delhi      M    charlie@example  20-07-2021
# 2      Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie    0        Delhi      M    charlie@example  20-07-2021
# 4    David   22       Mumbai      M  david@example.com  12-11-2019
# 5      NaN   28        Delhi      F     eve@domain.com         NaN
# 6    Alice   25     New York      F  alice@example.com  01-05-2021
# 7    Alice   25     New York      F  alice@example.com  01-05-2021
# 8  Charlie    0        Delhi      M    charlie@example  20-07-2021

# %%
df["Join Date"] = pd.to_datetime(df["Join Date"], format="mixed", errors="coerce")
df
# Out:
#       Name  Age         City Gender              Email  Join Date
# 0    Alice   25     New York      F  alice@example.com 2021-01-05
# 1  Charlie    0        Delhi      M    charlie@example 2021-07-20
# 2      Bob   30  Los Angeles      M    bob@example.com 2020-06-15
# 3  Charlie    0        Delhi      M    charlie@example 2021-07-20
# 4    David   22       Mumbai      M  david@example.com 2019-12-11
# 5      NaN   28        Delhi      F     eve@domain.com        NaT
# 6    Alice   25     New York      F  alice@example.com 2021-01-05
# 7    Alice   25     New York      F  alice@example.com 2021-01-05
# 8  Charlie    0        Delhi      M    charlie@example 2021-07-20

# %%
df["Age Group"] = df["Age"].apply(lambda x: "Adult" if x > 25 else "Minor")

# %%
df
# Out:
#       Name  Age         City Gender              Email  Join Date Age Group
# 0    Alice   25     New York      F  alice@example.com 2021-01-05     Minor
# 1  Charlie    0        Delhi      M    charlie@example 2021-07-20     Minor
# 2      Bob   30  Los Angeles      M    bob@example.com 2020-06-15     Adult
# 3  Charlie    0        Delhi      M    charlie@example 2021-07-20     Minor
# 4    David   22       Mumbai      M  david@example.com 2019-12-11     Minor
# 5      NaN   28        Delhi      F     eve@domain.com        NaT     Adult
# 6    Alice   25     New York      F  alice@example.com 2021-01-05     Minor
# 7    Alice   25     New York      F  alice@example.com 2021-01-05     Minor
# 8  Charlie    0        Delhi      M    charlie@example 2021-07-20     Minor

# %%
gender_map={"F": "Female", "M": "Male"}
df["Gender"] = df["Gender"].map(gender_map)

# %%
df
# Out:
#       Name  Age         City  Gender              Email  Join Date Age Group
# 0    Alice   25     New York  Female  alice@example.com 2021-01-05     Minor
# 1  Charlie    0        Delhi    Male    charlie@example 2021-07-20     Minor
# 2      Bob   30  Los Angeles    Male    bob@example.com 2020-06-15     Adult
# 3  Charlie    0        Delhi    Male    charlie@example 2021-07-20     Minor
# 4    David   22       Mumbai    Male  david@example.com 2019-12-11     Minor
# 5      NaN   28        Delhi  Female     eve@domain.com        NaT     Adult
# 6    Alice   25     New York  Female  alice@example.com 2021-01-05     Minor
# 7    Alice   25     New York  Female  alice@example.com 2021-01-05     Minor
# 8  Charlie    0        Delhi    Male    charlie@example 2021-07-20     Minor

# %%
df["City"].replace({"Delhi":"New Delhi", "New York": "NYK"})
# Out:
# 0            NYK
# 1      New Delhi
# 2    Los Angeles
# 3      New Delhi
# 4         Mumbai
# 5      New Delhi
# 6            NYK
# 7            NYK
# 8      New Delhi
# Name: City, dtype: str

# %%
df
# Out:
#       Name  Age         City  Gender              Email  Join Date Age Group
# 0    Alice   25     New York  Female  alice@example.com 2021-01-05     Minor
# 1  Charlie    0        Delhi    Male    charlie@example 2021-07-20     Minor
# 2      Bob   30  Los Angeles    Male    bob@example.com 2020-06-15     Adult
# 3  Charlie    0        Delhi    Male    charlie@example 2021-07-20     Minor
# 4    David   22       Mumbai    Male  david@example.com 2019-12-11     Minor
# 5      NaN   28        Delhi  Female     eve@domain.com        NaT     Adult
# 6    Alice   25     New York  Female  alice@example.com 2021-01-05     Minor
# 7    Alice   25     New York  Female  alice@example.com 2021-01-05     Minor
# 8  Charlie    0        Delhi    Male    charlie@example 2021-07-20     Minor
