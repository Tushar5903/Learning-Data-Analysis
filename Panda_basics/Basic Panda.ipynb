# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50,60])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
s = pd.Series([88,88,92],index=["Hindi","English","Maths"])

# %%
s
# Out:
# Hindi      88
# English    88
# Maths      92
# dtype: int64

# %%
# Data frame also work as the 2-D
data = {
    "name":["Tushar","Shivam","Kunal"],
    "age":[24,25,26],
    "city":["UP","Bihar","Delhi"]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#      name  age   city
# 0  Tushar   24     UP
# 1  Shivam   25  Bihar
# 2   Kunal   26  Delhi

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='str')
