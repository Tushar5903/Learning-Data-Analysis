# %%
import numpy as np

# %%
data = np.array([1,5,9,7,3,3])

# %%
data
# Out:
# array([1, 5, 9, 7, 3, 3])

# %%
np.mean(data)
# Out:
# np.float64(4.666666666666667)

# %%
np.std(data)
# Out:
# np.float64(2.6874192494328497)

# %%
print("variance: ", np.var(data))
# Out:
# variance:  7.222222222222221

# %%
print("Min: ", np.min(data))
# Out:
# Min:  1

# %%
print("Max: ", np.max(data))
# Out:
# Max:  9

# %%
print("Product: ", np.prod(data))
# Out:
# Product:  2835

# %%
print("Median: ", np.median(data))
# Out:
# Median:  4.0

# %%
print("Percentile: ", np.percentile(data,70))
# Out:
# Percentile:  6.0

# %%
print("Index of the minimum: ", np.argmin(data))
# Out:
# Index of the minimum:  0

# %%
print("Index of the maxmum: ", np.argmax(data))
# Out:
# Index of the maxmum:  2

# %%
data1 = np.array([7,8,9,5,3])
data2 = np.array([4,5,6,7,1])
print("Correlation coefficient: ", np.corrcoef(data1,data2))
# Out:
# Correlation coefficient:  [[1.         0.57716242]
#  [0.57716242 1.        ]]

# %%
print("Unique data list: ", np.unique(data))
# Out:
# Unique data list:  [1 3 5 7 9]

# %%
print("n-th difference of the array: ", np.diff(data))
# Out:
# n-th difference of the array:  [ 4  4 -2 -4  0]

# %%
print("Cumulative Sum: ", np.cumsum(data))
# Out:
# Cumulative Sum:  [ 1  6 15 22 25 28]

# %%
np.linspace(0,100,15)
# Out:
# array([  0.        ,   7.14285714,  14.28571429,  21.42857143,
#         28.57142857,  35.71428571,  42.85714286,  50.        ,
#         57.14285714,  64.28571429,  71.42857143,  78.57142857,
#         85.71428571,  92.85714286, 100.        ])

# %%
np.log(data)
# Out:
# array([0.        , 1.60943791, 2.19722458, 1.94591015, 1.09861229,
#        1.09861229])

# %%
np.exp(data)
# Out:
# array([2.71828183e+00, 1.48413159e+02, 8.10308393e+03, 1.09663316e+03,
#        2.00855369e+01, 2.00855369e+01])
